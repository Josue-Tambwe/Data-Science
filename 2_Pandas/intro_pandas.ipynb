# %% [markdown]
# Les structures des données avec le module Numpy étant bien organisées pour le calculs numériques, elles imposent certaines contraintes notamment les données doivent être de même type et préférablement numériques (int ou float). Ce qui rend impossible l'étiquetage des données.
# Toutefois, la bibliothèque **Pandas**, avec ses objets (**séries** et **dataframe**) non seulement pallie à ce problème d'étiquetage des données mais optimise la préparation, le nettoyage et l'analyse des données en gardant les fonctions de calcul de haute performance de la bibliothèque Numpy.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Série :
# un tableau uni-dimensionnel formé des lignes, lesquelles sont indéxées (par défaut par des entiers à partir de 0).
# Les indices n'ont pas de contraintes quant à leurs types.

# %%
serie1 = pd.Series([1, 3, 5, 9, 13])
serie1
# Out:
# 0     1
# 1     3
# 2     5
# 3     9
# 4    13
# dtype: int64

# %%
serie2 = pd.Series(data = [1, 3, 5, 9], index = ['a', True, 2.5, 0])
serie2
# Out:
# a       1
# True    3
# 2.5     5
# 0       9
# dtype: int64

# %%
serie3 = pd.Series(data = [2, 4, 6, 10], index = ['b', False, 3.5, 15])
serie3
# Out:
# b         2
# False     4
# 3.5       6
# 15       10
# dtype: int64

# %% [markdown]
# **Remarques** :
# 1. **S** est en majuscule
# 2. lorsque l'on ne met qu'une seule liste en argument (serie1), les indices sont les entiers à partir de 0
# 3. le cas de deux listes en arguments (serie3) où la première sera la liste des données et la suivant celle des indices

# %% [markdown]
# ## Accès aux éléments d'une série :
# Identique au fonctionnement des dictionnaires où l'indice (index) joue le rôle de la clé

# %%
print("serie1[0] = ", serie1[0])
print("serie2[True] = ", serie2[True])
print("serie3[3.5] = ", serie3[3.5])
# Out:
# serie1[0] =  1
# serie2[True] =  3
# serie3[3.5] =  6

# %% [markdown]
# ### Attribut : index
# On peut consulter la liste des indices d'une série avec l'attribut de la série:  ***index***

# %%
serie2.index
# Out:
# Index(['a', True, 2.5, 0], dtype='object')

# %% [markdown]
# ## Créer une série à partir d'un dictionnaire :
# les clés du dictionnaire deviendront les indices de la série

# %%
dict_heure = {"matin": 6, "midi": 12, "soir": 8}
serie4 = pd.Series(dict_heure)
serie4
# Out:
# matin     6
# midi     12
# soir      8
# dtype: int64

# %% [markdown]
# ### N'utiliser qu'une partie du dictionnaire :
# Dans l'argument **index**, mettre dans une liste toutes les clés pour lesquelles l'on souhaite conserver la valeur.

# %%
serie5 = pd.Series(dict_heure, index = ["midi", "soir"])
serie5
# Out:
# midi    12
# soir     8
# dtype: int64

# %% [markdown]
# ## Modifier un élément d'un indice

# %%
serie5["midi"] = 13
serie5
# Out:
# midi    13
# soir     8
# dtype: int64

# %% [markdown]
# ## Ajouter des élément dans une série :
# identique à l'ajout d'un élément dans un dictionnaire

# %%
serie5["nuit"] = 12
serie5
# Out:
# midi    13
# soir     8
# nuit    12
# dtype: int64

# %% [markdown]
# ## Filtrer sur les valeurs d'une série

# %%
serie6 = pd.Series([15, 34, 7, 11, 9, 19], ['a', 'b', 'c', 'd', 'e', 'f'])
serie6[serie6 >= 10]
# Out:
# a    15
# b    34
# d    11
# f    19
# dtype: int64

# %% [markdown]
# ### Possibilité de combiner plusieurs critères (conditions) dans le filtre

# %%
serie6[(serie6 >= 10) & (serie6 <= 15)]
# Out:
# a    15
# d    11
# dtype: int64

# %% [markdown]
# # DataFrame :
# Structure des données tabulaire bi-dimensionnelle, orienté colonnes, avec des étiquettes (indices) sur les lignes et les colonnes

# %% [markdown]
# ## Créer une dataframe partant d'une série :
# Sachant que pour les séries, les indices des lignes sont déjà définis, il ne reste plus qu'à donner un nom (une étiquette) à la colonne (dans une liste à un seul élément)

# %%
dataframe1 = pd.DataFrame(serie5, columns = ["Heures"])
dataframe1
# Out:
#       Heures
# midi      13
# soir       8
# nuit      12

# %% [markdown]
# ## Créer une dataframe partant de plusieurs dictionnaires:
# Les clés uniques des dictionnaires formeront les étiques des colonnes de la dataframe,, d'où une organisation des dictionnaires avec les mêmes noms des clés permettra une cohérence de la dataframe où chaque ligne (dictionnaire) sera vu comme un enregistrement d'une table (comme dans les bases des données)

# %%
d1 = {"Nom": "a", "Ville": "Nantes", "Score" : 10}
d2 = {"Nom": "b", "Ville": "Angers", "Score" : 12}
d3 = {"Nom": "c", "Ville": "Rennes", "Score" : 14}
d4 = {"Nom": "d", "Ville": "Paris", "Score" : 16}
d5 = {"Nom": "e", "Ville": "Lyon", "Score" : 18}
dataframe2 = pd.DataFrame([d1, d2, d3, d4, d5])
dataframe2
# Out:
#   Nom   Ville  Score
# 0   a  Nantes     10
# 1   b  Angers     12
# 2   c  Rennes     14
# 3   d   Paris     16
# 4   e    Lyon     18

# %% [markdown]
# ### Dictionnaire définie en compréhension (avec une boucle **for**) :

# %%
liste_dic = [{"valeur_i" : i, "double_i": 2*i, "carre_i": i*i} for i in range(10)]
dataframe3 = pd.DataFrame(liste_dic)
dataframe3
# Out:
#    valeur_i  double_i  carre_i
# 0         0         0        0
# 1         1         2        1
# 2         2         4        4
# 3         3         6        9
# 4         4         8       16
# 5         5        10       25
# 6         6        12       36
# 7         7        14       49
# 8         8        16       64
# 9         9        18       81

# %% [markdown]
# ### Partant d'une matrice Numpy :

# %%
mat = np.random.randint(0, 11, (4,3))
print(mat)
dataframe4 = pd.DataFrame(mat, columns = ["col_1", "col_2", "col_3"], index = ["ligne_1", "ligne_2", "ligne_3", "ligne_4"])
dataframe4
# Out:
# [[0 8 2]
#  [5 8 1]
#  [6 2 9]
#  [4 5 8]]
#          col_1  col_2  col_3
# ligne_1      0      8      2
# ligne_2      5      8      1
# ligne_3      6      2      9
# ligne_4      4      5      8

# %% [markdown]
# ## Modifier une Dataframe :

# %% [markdown]
# ### Ajout d'une colonne

# %%
mat = np.random.randint(0, 21, (5, 2))
notes = pd.DataFrame(mat, columns = ["Maths", "Physique"], index = ["Christophe", "Clara", "Benjamin", "Amine", "Jason"])
print(notes)
notes["Moyenne"] = (notes["Maths"] + notes["Physique"])/2
notes
# Out:
#             Maths  Physique
# Christophe      9        20
# Clara           3         2
# Benjamin        0         2
# Amine           4        12
# Jason          15         2
#             Maths  Physique  Moyenne
# Christophe      9        20     14.5
# Clara           3         2      2.5
# Benjamin        0         2      1.0
# Amine           4        12      8.0
# Jason          15         2      8.5

# %% [markdown]
# ## Accéder à des données

# %% [markdown]
# ### Afficher une colonne :
# Il est préférable de mettre l'étiquette (nom) de la colonne entre crochet, comme une liste à un seul élément, pour avoir un affiche plus agréable que celui qui est rendu lorsque l'on ne met pas l'étiquette dans une liste avec la syntaxe notes\["Maths"] (cette syntaxe est correcte tout de même).

# %%
notes[["Physique"]]
# Out:
#             Physique
# Christophe        20
# Clara              2
# Benjamin           2
# Amine             12
# Jason              2

# %% [markdown]
# ### Afficher plusieurs colonnes :
# Mettre plusieurs étiquettes dans la liste.

# %%
notes[["Maths", "Moyenne"]]
# Out:
#             Maths  Moyenne
# Christophe      9     14.5
# Clara           3      2.5
# Benjamin        0      1.0
# Amine           4      8.0
# Jason          15      8.5

# %% [markdown]
# ### Accès à une ligne :
# Avec : **loc\[index]**, où *index* est  l'étiquette de la ligne souhaitée
# N.B : ici "Christophe" a un "C" majuscule, il faut que l'étique soitexactement le même que celui dans la dataframe.

# %%
notes.loc["Christophe"]
# Out:
# Maths        9.0
# Physique    20.0
# Moyenne     14.5
# Name: Christophe, dtype: float64

# %% [markdown]
# ### Accès à un élément spécifique (ligne + colonne) :
# Avec **loc\[index, column]**, où *index* est l'étiquette de la ligne et *column* celui de la colonne

# %%
notes.loc["Clara", "Moyenne"]
# Out:
# 2.5

# %% [markdown]
# ### Cas des valeurs manquantes :
# En supposant ques les dictionnaires ont les mêmes noms des clés (pour des raisons de cohérence), alors si les dictionnaires n'ont pas le même nombre d'éléments, les valeurs manquantes seront remplies par NaN (Not a Number)

# %%
d1 = {"Nom": "a", "Ville": "Nantes", "Score" : 10}
d2 = {"Nom": "b", "Score" : 12}
d3 = {"Nom": "c", "Ville": "Rennes", "Score" : 14}
d4 = {"Ville": "Paris", "Score" : 16}
d5 = {"Nom": "e", "Ville": "Lyon"}
dataframe2 = pd.DataFrame([d1, d2, d3, d4, d5])
dataframe2
# Out:
#    Nom   Ville  Score
# 0    a  Nantes   10.0
# 1    b     NaN   12.0
# 2    c  Rennes   14.0
# 3  NaN   Paris   16.0
# 4    e    Lyon    NaN

# %% [markdown]
# ## Supression dans une Dataframe :
# Pour faire l'analogie avec la table d'une base des données, on peut supprimer des lignes (enregistrements) ou des colonnes (champs) dans une Dataframe.
# Pour ce faire le premier argument est l'étiquette à supprimer (ligne ou colonne), le second argument est **axis** qui doit être mis à **0** pour supprimer une ligne (enregistrement), et à **1** pour supprimer une colonne (champ). Le dernier argument : **inplace** qui doit prendre la valeur *True* ou *False*, selon que l'on veut supprimer directement dans la dataframe ou juste supprimer lors de l'affichage, toutefois **la dataframe originale reste intacte** (il est par défaut à False).

# %% [markdown]
# #### Supprimer une colonne :

# %%
notes.drop("Physique", axis = 1, inplace = False)
# Out:
#             Maths  Moyenne
# Christophe      9     14.5
# Clara           3      2.5
# Benjamin        0      1.0
# Amine           4      8.0
# Jason          15      8.5

# %%
notes
# Out:
#             Maths  Physique  Moyenne
# Christophe      9        20     14.5
# Clara           3         2      2.5
# Benjamin        0         2      1.0
# Amine           4        12      8.0
# Jason          15         2      8.5

# %%
notes.drop("Physique", axis = 1, inplace = True)
notes
# Out:
#             Maths  Moyenne
# Christophe      9     14.5
# Clara           3      2.5
# Benjamin        0      1.0
# Amine           4      8.0
# Jason          15      8.5

# %% [markdown]
# #### Supprimer une ligne :

# %%
notes.drop("Clara", axis = 0, inplace = True)

# %%
notes
# Out:
#             Maths  Moyenne
# Christophe      9     14.5
# Benjamin        0      1.0
# Amine           4      8.0
# Jason          15      8.5

# %% [markdown]
# ## Sélection des données dans une dataframe :

# %%
# tableau aléatoire des valeurs (notes) entre 0 et 20 (car 21 exclut)
tab1 = np.random.randint(0, 21, (5))
# liste des étudiants
tab2 = ["Christophe", "Clara", "Amine", "Amandine", "Lina"]
# notes de Maths
dic_maths = {tab2[i] : tab1[i] for i in range(len(tab1))}
# Série des notes de maths
serie_math = pd.Series(dic_maths)
# De même pour le cours de Physique
tab1 = np.random.randint(0, 21, (5))
dic_physique = {tab2[i] : tab1[i] for i in range(len(tab1))}
serie_physique = pd.Series(dic_physique)
# la dataframe
notes = pd.DataFrame({"Maths": dic_maths, "Physique": dic_physique})
notes["Moyenne"] = (notes["Maths"] + notes["Physique"])/2
notes
# Out:
#             Maths  Physique  Moyenne
# Christophe      3         9      6.0
# Clara           2         5      3.5
# Amine           1        12      6.5
# Amandine        8        17     12.5
# Lina            2         3      2.5

# %% [markdown]
#  **Remarques** : Etant donné que la dataframe "**notes**"  est construite à partir d'**un seul dictionnaire**, dont les deux clés sont "Maths et Physiques" et les **valeurs sont eux mêmes des dictionnaires**, le remplissage de la dataframe 'note' se déroulera de la manière suivante :
#
#  1. Les étiques des colonnes de la dataframe seront les deux clés du dictionnaire en argument que sont **'Maths'** et **'Physique'**
#  2. Dans un premier temps, la valeur de la clé 'Maths' :
#     - Cette valeur étant elle même un dictionnaire (dic_maths), de ce fait toutes les clés de **dic_maths** étiquetteront les lignes de la dataframe et la première colonne sera rempli entièrement en mettant la valeur d'une clé à l'emplacement convenable (intersection ligne et première colonne)
#  3. Dans un second temps, tooutes les clés du second dictionnaire (dic_physique) vont être ajouter pour étiquetter les lignes suivantes de la dataframe 'note' **si, et seulement si**, ces étiquêtes n'étaient pas déjà présentes dans la dataframe
#      - La seconde colonne sera alors complètement rempli à son tour.
#  4. Les valeurs manquantes seront rempli par NaN dans la dataframe

# %% [markdown]
# ### Sélection d'une colonne :
# Mettre l'étiquette (nom) de la colonne entre crochet

# %%
notes["Moyenne"]
# Out:
# Christophe     6.0
# Clara          3.5
# Amine          6.5
# Amandine      12.5
# Lina           2.5
# Name: Moyenne, dtype: float64

# %% [markdown]
# Autre façon de faire : mettre un point (**.**) + le nom de la colonne

# %%
notes.Maths
# Out:
# Christophe    3
# Clara         2
# Amine         1
# Amandine      8
# Lina          2
# Name: Maths, dtype: int32

# %% [markdown]
# ### Sélection avec *iloc[]* :
# Les lignes et colonnes sont indéxées par des entiers partant de 0, comme dans un tableau bi-dimensionnel de Numpy

# %%
notes.iloc[2]
# Out:
# Maths        1.0
# Physique    12.0
# Moyenne      6.5
# Name: Amine, dtype: float64

# %% [markdown]
# ### Sélection avec *loc[]* qui prend deux listes en argument :
# La première liste contiendra les étiquettes des lignes à récupérer et la deuxième liste, les étiquettes des colonnes.

# %%
notes.loc[["Christophe", "Lina"], ["Maths", "Moyenne"]]
# Out:
#             Maths  Moyenne
# Christophe      3      6.0
# Lina            2      2.5

# %% [markdown]
# ## Sélection par tranche :
# **loc\[**debut_ligne : fin_ligne, debut_colonne : fin_colonne**]** avec :
# - debut_ligne (fin_ligne) : l'étiquette par laquelle on souhaite débuter (terminer)
# - Si l'on veut toutes les lignes (toutes les colonnes) alors  : loc\[    **:**    , debut_colonne : fin_colonne] (loc\[debut_ligne : fin_ligne,    **:**   ])

# %%
notes.loc["Clara" : "Amandine", "Physique" : "Moyenne"]
# Out:
#           Physique  Moyenne
# Clara            5      3.5
# Amine           12      6.5
# Amandine        17     12.5

# %%
notes.loc["Clara" : "Amandine", : ]
# Out:
#           Maths  Physique  Moyenne
# Clara         2         5      3.5
# Amine         1        12      6.5
# Amandine      8        17     12.5

# %%
notes.loc[ : , "Physique" : "Moyenne"]
# Out:
#             Physique  Moyenne
# Christophe         9      6.0
# Clara              5      3.5
# Amine             12      6.5
# Amandine          17     12.5
# Lina               3      2.5

# %%
notes.loc["Clara" : ,  : "Moyenne"]
# Out:
#           Maths  Physique  Moyenne
# Clara         2         5      3.5
# Amine         1        12      6.5
# Amandine      8        17     12.5
# Lina          2         3      2.5

# %% [markdown]
# #### Remarques : On peut séléctionner par tranche avec ***iloc[]***, cette fois les entiers (à partir de 0) idexeront les lignes et les colonnes.

# %% [markdown]
# ## Sélection Conditionnelle

# %% [markdown]
# #### Cas 1 : un tableau bi_dimensionnel des valeurs booléens dans lesquel une cellule est **True** si la valeur vérifie la condition et **False** sinon.

# %%
notes > 10
# Out:
#             Maths  Physique  Moyenne
# Christophe  False     False    False
# Clara       False     False    False
# Amine       False      True    False
# Amandine    False      True     True
# Lina        False     False    False

# %% [markdown]
# #### Cas 2 :  On souhaite récupérer (afficher) les valeurs vérifiant condition (**NaN** lorsqu'elle n'est pas vérifiée)

# %%
notes[notes > 10]
# Out:
#             Maths  Physique  Moyenne
# Christophe    NaN       NaN      NaN
# Clara         NaN       NaN      NaN
# Amine         NaN      12.0      NaN
# Amandine      NaN      17.0     12.5
# Lina          NaN       NaN      NaN

# %% [markdown]
# #### Cas 3 : Condition uni-dimensionnel (colonne)

# %%
notes["Physique"] > 10
# Out:
# Christophe    False
# Clara         False
# Amine          True
# Amandine       True
# Lina          False
# Name: Physique, dtype: bool

# %%
notes[notes["Physique"] > 10]
# Out:
#           Maths  Physique  Moyenne
# Amine         1        12      6.5
# Amandine      8        17     12.5

# %% [markdown]
# #### **Remarque** : Les lignes ne vérifiant pas la codition sont ignorées.

# %% [markdown]
# #### Cas 4 : Afficher une colonne pour laquelle une condition sur une autre colonne a été satisfaite:
# Afficher la note en 'Maths' des étudiants, uniquement s'ils ont une moyenne **supérieure ou égale à 10**
# (Premier filtre sur la moyenne et ensuite on affiche uniquement la colonne 'Maths')

# %%
notes[notes["Moyenne"] >= 10]["Maths"]
# Out:
# Amandine    8
# Name: Maths, dtype: int32

# %% [markdown]
# ##### Pour un meilleur rendu de l'affichage il est conseillé de mettre la deuxième étique de la colonne dans une liste (ici "Maths")

# %%
notes[notes["Moyenne"] >= 10][["Maths"]]
# Out:
#           Maths
# Amandine      8

# %% [markdown]
# #### Cas 5 :  Afficher plusieurs colonnes pour laquelle une condition sur une autre colonne a été satisfaite :
# On rajoute les étiquettes des colonnes souhaitées dans la liste du deuxième crochet.

# %%
notes[notes["Moyenne"] >= 10][["Physique", "Maths"]]
# Out:
#           Physique  Maths
# Amandine        17      8

# %% [markdown]
# # Lecture d'un fichier CSV (comma separeted values) :
# Avec la méthode **read_csv()** de la bibliothèque Pandas on peut lire des fichiers **csv**. Mais parfois, il convient de rajouter certains paramètre supplémentaire à cette méthode notmment **l'encodage** (encoding) etc...le cas échéant.

# %%
import os
print(os.listdir())
dataframe = pd.read_csv("Order_v3.csv", encoding = 'latin1')
dataframe
# Out:
# ['.ipynb_checkpoints', 'data', 'intro_pandas.ipynb', 'Order_v3.csv']
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 0          100044349  OUTBOUND                     LightTree
# 1          100044350  OUTBOUND                     LightTree
# 2          100044353  OUTBOUND                     LightTree
# 3          100055001  OUTBOUND                     LightTree
# 4          100055003  OUTBOUND                     LightTree
# ..               ...       ...                           ...
# 209        100044330  OUTBOUND                     LightTree
# 210        100044331  OUTBOUND                     LightTree
# 211        100044332  OUTBOUND                     LightTree
# 212        100055004  OUTBOUND                     LightTree
# 213        100055011  OUTBOUND                     LightTree
#
#     buyer.organizationIdentifier  \
# 0                           AHTD
# 1                           AHTD
# 2                           AHTD
# 3                           AHTD
# 4                           AHTD
# ..                           ...
# 209                         QPWD
# 210                         QPWD
# 211                         QPWD
# 212                         QPWD
# 213                         QPWD
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-1
# 1                                             LT-1
# 2                                             LT-1
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 209                                           LT-2
# 210                                           LT-2
# 211                                           LT-2
# 212                                           LT-2
# 213                                           LT-2
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 0                  AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 1                  AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 2                  AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 3                  AHTD - Bentonville          NaN  2017-07-11T00:00:00
# 4                  AHTD - Bentonville          NaN  2017-07-20T00:00:00
# ..                                ...          ...                  ...
# 209            QPWD - Ville de Québec          NaN  2021-07-07T00:00:00
# 210            QPWD - Ville de Québec          NaN  2021-07-07T00:00:00
# 211            QPWD - Ville de Québec          NaN  2021-07-07T00:00:00
# 212            QPWD - Ville de Québec          NaN  2017-07-11T00:00:00
# 213            QPWD - Ville de Québec          NaN  2017-07-11T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0    2021-07-20T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 1    2021-07-23T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 2    2021-07-13T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 3    2021-08-10T00:00:00   2021-08-18T00:00:00  2021-08-10T00:00:00
# 4    2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# ..                   ...                   ...                  ...
# 209  2021-08-06T00:00:00   2021-08-12T00:00:00  2021-08-06T00:00:00
# 210  2021-08-04T00:00:00   2021-08-12T00:00:00  2021-08-06T00:00:00
# 211  2021-08-21T00:00:00   2021-08-27T00:00:00  2021-08-21T00:00:00
# 212  2021-08-10T00:00:00   2021-08-18T00:00:00                  NaN
# 213  2021-08-10T00:00:00   2021-08-18T00:00:00  2021-08-10T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  totalValue  \
# 0    2021-07-30T00:00:00       189            EA    236250.0
# 1    2021-07-30T00:00:00        20            EA     25000.0
# 2    2021-07-30T00:00:00       212            EA    265000.0
# 3    2021-08-18T00:00:00       761            EA     59473.0
# 4    2021-08-14T00:00:00       520            EA     47438.0
# ..                   ...       ...           ...         ...
# 209  2021-08-12T00:00:00        12            EA     15000.0
# 210  2021-08-12T00:00:00       960            EA   1200000.0
# 211  2021-08-27T00:00:00        56            EA     70000.0
# 212                  NaN       597            EA     44953.0
# 213  2021-08-18T00:00:00       447            EA     27319.0
#
#     orderValueCurrency  lineCount  totalShippedQuantity  exclude  \
# 0                  USD          3                   NaN      NaN
# 1                  USD          3                   NaN      NaN
# 2                  USD          3                   NaN      NaN
# 3                  USD          3                   NaN      NaN
# 4                  USD          3                   NaN      NaN
# ..                 ...        ...                   ...      ...
# 209                USD          3                   NaN      NaN
# 210                USD          3                   NaN      NaN
# 211                USD          3                   NaN      NaN
# 212                USD          3                   NaN      NaN
# 213                USD          4                   NaN      NaN
#
#                          sourceLink
# 0    http://lighttree.com/100044349
# 1    http://lighttree.com/100044350
# 2    http://lighttree.com/100044353
# 3    http://lighttree.com/100055001
# 4    http://lighttree.com/100055003
# ..                              ...
# 209  http://lighttree.com/100044330
# 210  http://lighttree.com/100044331
# 211  http://lighttree.com/100044332
# 212  http://lighttree.com/100055004
# 213  http://lighttree.com/100055011
#
# [214 rows x 20 columns]

# %% [markdown]
# ## Quelques commandes à connaitre :

# %% [markdown]
# ### 1. Afficher les 5 premières lignes

# %%
dataframe.head()
# Out:
#    orderIdentifier orderType vendor.organizationIdentifier  \
# 0        100044349  OUTBOUND                     LightTree
# 1        100044350  OUTBOUND                     LightTree
# 2        100044353  OUTBOUND                     LightTree
# 3        100055001  OUTBOUND                     LightTree
# 4        100055003  OUTBOUND                     LightTree
#
#   buyer.organizationIdentifier shipFromInstructionLocation.locationIdentifier  \
# 0                         AHTD                                           LT-1
# 1                         AHTD                                           LT-1
# 2                         AHTD                                           LT-1
# 3                         AHTD                                           LT-2
# 4                         AHTD                                           LT-2
#
#   shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 0                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 1                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 2                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 3                AHTD - Bentonville          NaN  2017-07-11T00:00:00
# 4                AHTD - Bentonville          NaN  2017-07-20T00:00:00
#
#      requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0  2021-07-20T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 1  2021-07-23T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 2  2021-07-13T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 3  2021-08-10T00:00:00   2021-08-18T00:00:00  2021-08-10T00:00:00
# 4  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
#
#    plannedDeliveryDate  quantity quantityUnits  totalValue orderValueCurrency  \
# 0  2021-07-30T00:00:00       189            EA    236250.0                USD
# 1  2021-07-30T00:00:00        20            EA     25000.0                USD
# 2  2021-07-30T00:00:00       212            EA    265000.0                USD
# 3  2021-08-18T00:00:00       761            EA     59473.0                USD
# 4  2021-08-14T00:00:00       520            EA     47438.0                USD
#
#    lineCount  totalShippedQuantity  exclude                      sourceLink
# 0          3                   NaN      NaN  http://lighttree.com/100044349
# 1          3                   NaN      NaN  http://lighttree.com/100044350
# 2          3                   NaN      NaN  http://lighttree.com/100044353
# 3          3                   NaN      NaN  http://lighttree.com/100055001
# 4          3                   NaN      NaN  http://lighttree.com/100055003

# %% [markdown]
# ### 2. Afficher les 5 premières lignes

# %%
dataframe.head()
# Out:
#    orderIdentifier orderType vendor.organizationIdentifier  \
# 0        100044349  OUTBOUND                     LightTree
# 1        100044350  OUTBOUND                     LightTree
# 2        100044353  OUTBOUND                     LightTree
# 3        100055001  OUTBOUND                     LightTree
# 4        100055003  OUTBOUND                     LightTree
#
#   buyer.organizationIdentifier shipFromInstructionLocation.locationIdentifier  \
# 0                         AHTD                                           LT-1
# 1                         AHTD                                           LT-1
# 2                         AHTD                                           LT-1
# 3                         AHTD                                           LT-2
# 4                         AHTD                                           LT-2
#
#   shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 0                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 1                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 2                AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 3                AHTD - Bentonville          NaN  2017-07-11T00:00:00
# 4                AHTD - Bentonville          NaN  2017-07-20T00:00:00
#
#      requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0  2021-07-20T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 1  2021-07-23T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 2  2021-07-13T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 3  2021-08-10T00:00:00   2021-08-18T00:00:00  2021-08-10T00:00:00
# 4  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
#
#    plannedDeliveryDate  quantity quantityUnits  totalValue orderValueCurrency  \
# 0  2021-07-30T00:00:00       189            EA    236250.0                USD
# 1  2021-07-30T00:00:00        20            EA     25000.0                USD
# 2  2021-07-30T00:00:00       212            EA    265000.0                USD
# 3  2021-08-18T00:00:00       761            EA     59473.0                USD
# 4  2021-08-14T00:00:00       520            EA     47438.0                USD
#
#    lineCount  totalShippedQuantity  exclude                      sourceLink
# 0          3                   NaN      NaN  http://lighttree.com/100044349
# 1          3                   NaN      NaN  http://lighttree.com/100044350
# 2          3                   NaN      NaN  http://lighttree.com/100044353
# 3          3                   NaN      NaN  http://lighttree.com/100055001
# 4          3                   NaN      NaN  http://lighttree.com/100055003

# %% [markdown]
# ### 3. Afficher aléatoirement n (entier) enregistrements (lignes)

# %%
dataframe.sample(10)
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 178       1000567423   INBOUND                        Ripley
# 87        1000567418   INBOUND                     Alumi-lux
# 212        100055004  OUTBOUND                     LightTree
# 185       1000567449   INBOUND                          Amos
# 48        1000567286   INBOUND                       Brewers
# 125       1000066011   INBOUND                         F & M
# 22         100044327  OUTBOUND                     LightTree
# 103       1000567467   INBOUND                         Hardy
# 122       1000066008   INBOUND                         F & M
# 195       1000567481   INBOUND                        McGrey
#
#     buyer.organizationIdentifier  \
# 178                    LightTree
# 87                     LightTree
# 212                         QPWD
# 185                    LightTree
# 48                     LightTree
# 125                    LightTree
# 22                          COLA
# 103                    LightTree
# 122                    LightTree
# 195                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# 178                               Ripley - Trenton
# 87                              Alumi-lux - Nashua
# 212                                           LT-2
# 185                            Amos - Philadelphia
# 48                               Brewers - Phoenix
# 125                               F & M - Columbus
# 22                                            LT-2
# 103                                 Hardy - Salina
# 122                               F & M - Columbus
# 195                           McGrey - Mt Sterling
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 178                              LT-2          NaN  2021-06-16T00:00:00
# 87                               LT-1          NaN  2021-06-16T00:00:00
# 212            QPWD - Ville de Québec          NaN  2017-07-11T00:00:00
# 185                              LT-2          NaN  2021-06-16T00:00:00
# 48                               LT-1          NaN  2021-07-15T00:00:00
# 125                              LT-2          NaN  2021-07-01T00:00:00
# 22                  COLA - Los Alamos          NaN  2021-07-11T00:00:00
# 103                              LT-1          NaN  2021-06-16T00:00:00
# 122                              LT-2          NaN  2021-07-01T00:00:00
# 195                              LT-2          NaN  2021-06-16T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 178  2021-06-23T00:00:00   2021-06-27T00:00:00  2021-06-23T00:00:00
# 87   2021-06-23T00:00:00   2021-06-27T00:00:00  2021-06-23T00:00:00
# 212  2021-08-10T00:00:00   2021-08-18T00:00:00                  NaN
# 185  2021-06-23T00:00:00   2021-06-27T00:00:00  2021-06-23T00:00:00
# 48   2021-07-22T00:00:00   2021-07-26T00:00:00  2021-07-22T00:00:00
# 125  2021-09-23T00:00:00   2021-09-26T00:00:00  2021-09-23T00:00:00
# 22   2021-08-02T00:00:00   2021-08-10T00:00:00  2021-08-02T00:00:00
# 103  2021-06-23T00:00:00   2021-06-27T00:00:00  2021-06-23T00:00:00
# 122  2021-08-24T00:00:00   2021-08-27T00:00:00  2021-08-24T00:00:00
# 195  2021-06-23T00:00:00   2021-06-27T00:00:00  2021-06-23T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  totalValue  \
# 178  2021-06-27T00:00:00       124            EA     43400.0
# 87   2021-06-27T00:00:00       124            EA     56420.0
# 212                  NaN       597            EA     44953.0
# 185  2021-06-27T00:00:00       124            EA      6820.0
# 48                   NaN        44            EA     56628.0
# 125  2021-09-26T00:00:00      1400            EA    109900.0
# 22   2021-08-11T00:00:00        12            EA     15000.0
# 103  2021-06-27T00:00:00       512            EA     12288.0
# 122  2021-08-27T00:00:00      1400            EA    109900.0
# 195  2021-06-27T00:00:00       320            EA    316800.0
#
#     orderValueCurrency  lineCount  totalShippedQuantity  exclude  \
# 178                USD          1                   NaN      NaN
# 87                 USD          1                   NaN      NaN
# 212                USD          3                   NaN      NaN
# 185                USD          1                   NaN      NaN
# 48                 USD          1                   NaN      NaN
# 125                USD          4                   NaN      NaN
# 22                 USD          3                   NaN      NaN
# 103                USD          1                   NaN      NaN
# 122                USD          4                   NaN      NaN
# 195                USD          1                   NaN      NaN
#
#                           sourceLink
# 178  http://lighttree.com/1000567423
# 87   http://lighttree.com/1000567418
# 212   http://lighttree.com/100055004
# 185  http://lighttree.com/1000567449
# 48   http://lighttree.com/1000567286
# 125   http://lighttree.com/100055011
# 22    http://lighttree.com/100044327
# 103  http://lighttree.com/1000567467
# 122   http://lighttree.com/100055008
# 195  http://lighttree.com/1000567481

# %% [markdown]
# ### 4. Donner des informations sur la structure de la Datframe

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   orderIdentifier                                 214 non-null    int64
#  1   orderType                                       214 non-null    object
#  2   vendor.organizationIdentifier                   214 non-null    object
#  3   buyer.organizationIdentifier                    214 non-null    object
#  4   shipFromInstructionLocation.locationIdentifier  214 non-null    object
#  5   shipToLocation.locationIdentifier               214 non-null    object
#  6   orderStatus                                     0 non-null      float64
#  7   createdDate                                     214 non-null    object
#  8   requestedShipDate                               214 non-null    object
#  9   requestedDeliveryDate                           214 non-null    object
#  10  plannedShipDate                                 210 non-null    object
#  11  plannedDeliveryDate                             193 non-null    object
#  12  quantity                                        214 non-null    int64
#  13  quantityUnits                                   214 non-null    object
#  14  totalValue                                      214 non-null    float64
#  15  orderValueCurrency                              214 non-null    object
#  16  lineCount                                       214 non-null    int64
#  17  totalShippedQuantity                            0 non-null      float64
#  18  exclude                                         0 non-null      float64
#  19  sourceLink                                      214 non-null    object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 33.6+ KB

# %% [markdown]
# ### 5. Statistiques sur les colonnes numériques

# %%
dataframe.describe()
# Out:
#        orderIdentifier  orderStatus     quantity    totalValue   lineCount  \
# count     2.140000e+02          0.0   214.000000  2.140000e+02  214.000000
# mean      8.069695e+08          NaN   278.098131  1.229496e+05    1.607477
# std       3.707773e+08          NaN   325.289506  2.411097e+05    1.023269
# min       1.000443e+08          NaN     4.000000  1.320000e+02    1.000000
# 25%       1.000066e+09          NaN    74.250000  7.044000e+03    1.000000
# 50%       1.000567e+09          NaN   124.000000  3.904000e+04    1.000000
# 75%       1.000567e+09          NaN   320.000000  1.210240e+05    3.000000
# max       1.000568e+09          NaN  1400.000000  1.769600e+06    4.000000
#
#        totalShippedQuantity  exclude
# count                   0.0      0.0
# mean                    NaN      NaN
# std                     NaN      NaN
# min                     NaN      NaN
# 25%                     NaN      NaN
# 50%                     NaN      NaN
# 75%                     NaN      NaN
# max                     NaN      NaN

# %% [markdown]
# ### 6. Les accès aux donner :
# Lefonctionnement identique à celui de l'accès aux données d'une dataframe clasique

# %% [markdown]
# # Trier selon une colonne de la dataframe :
#
# Le premier paramètre est le nom (étiquette) de la colonne et le second est l'ordre (croissant ou Non) du trie

# %%
dataframe.sort_values("quantity", ascending = False)
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 117       1000066003   INBOUND                  Total Source
# 115       1000066001   INBOUND                  Total Source
# 123       1000066009   INBOUND                         F & M
# 122       1000066008   INBOUND                         F & M
# 121       1000066007   INBOUND                         F & M
# ..               ...       ...                           ...
# 1          100044350  OUTBOUND                     LightTree
# 21         100044326  OUTBOUND                     LightTree
# 209        100044330  OUTBOUND                     LightTree
# 22         100044327  OUTBOUND                     LightTree
# 31         100044337  OUTBOUND                     LightTree
#
#     buyer.organizationIdentifier  \
# 117                    LightTree
# 115                    LightTree
# 123                    LightTree
# 122                    LightTree
# 121                    LightTree
# ..                           ...
# 1                           AHTD
# 21                          COLA
# 209                         QPWD
# 22                          COLA
# 31                          KYTC
#
#     shipFromInstructionLocation.locationIdentifier  \
# 117                        Total Source - Waukesha
# 115                        Total Source - Waukesha
# 123                               F & M - Columbus
# 122                               F & M - Columbus
# 121                               F & M - Columbus
# ..                                             ...
# 1                                             LT-1
# 21                                            LT-2
# 209                                           LT-2
# 22                                            LT-2
# 31                                            LT-2
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 117                              LT-2          NaN  2021-07-01T00:00:00
# 115                              LT-2          NaN  2021-07-01T00:00:00
# 123                              LT-2          NaN  2021-07-01T00:00:00
# 122                              LT-2          NaN  2021-07-01T00:00:00
# 121                              LT-2          NaN  2021-07-01T00:00:00
# ..                                ...          ...                  ...
# 1                  AHTD - Bentonville          NaN  2021-06-08T00:00:00
# 21                  COLA - Los Alamos          NaN  2021-07-11T00:00:00
# 209            QPWD - Ville de Québec          NaN  2021-07-07T00:00:00
# 22                  COLA - Los Alamos          NaN  2021-07-11T00:00:00
# 31                   KYTC - Lexington          NaN  2021-06-28T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 117  2021-09-03T00:00:00   2021-09-06T00:00:00  2021-09-04T00:00:00
# 115  2021-08-14T00:00:00   2021-08-17T00:00:00  2021-08-14T00:00:00
# 123  2021-09-03T00:00:00   2021-09-06T00:00:00  2021-09-04T00:00:00
# 122  2021-08-24T00:00:00   2021-08-27T00:00:00  2021-08-24T00:00:00
# 121  2021-08-14T00:00:00   2021-08-17T00:00:00  2021-08-14T00:00:00
# ..                   ...                   ...                  ...
# 1    2021-07-23T00:00:00   2021-07-30T00:00:00  2021-07-23T00:00:00
# 21   2021-08-02T00:00:00   2021-08-10T00:00:00  2021-08-02T00:00:00
# 209  2021-08-06T00:00:00   2021-08-12T00:00:00  2021-08-06T00:00:00
# 22   2021-08-02T00:00:00   2021-08-10T00:00:00  2021-08-02T00:00:00
# 31   2021-07-28T00:00:00   2021-08-01T00:00:00  2021-07-28T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  totalValue  \
# 117  2021-09-07T00:00:00      1400            EA    226800.0
# 115  2021-08-17T00:00:00      1400            EA    226800.0
# 123  2021-09-07T00:00:00      1400            EA    109900.0
# 122  2021-08-27T00:00:00      1400            EA    109900.0
# 121  2021-08-17T00:00:00      1400            EA    109900.0
# ..                   ...       ...           ...         ...
# 1    2021-07-30T00:00:00        20            EA     25000.0
# 21   2021-08-10T00:00:00        12            EA     15000.0
# 209  2021-08-12T00:00:00        12            EA     15000.0
# 22   2021-08-11T00:00:00        12            EA     15000.0
# 31   2021-08-01T00:00:00         4            EA      5000.0
#
#     orderValueCurrency  lineCount  totalShippedQuantity  exclude  \
# 117                USD          4                   NaN      NaN
# 115                USD          4                   NaN      NaN
# 123                USD          4                   NaN      NaN
# 122                USD          4                   NaN      NaN
# 121                USD          4                   NaN      NaN
# ..                 ...        ...                   ...      ...
# 1                  USD          3                   NaN      NaN
# 21                 USD          3                   NaN      NaN
# 209                USD          3                   NaN      NaN
# 22                 USD          3                   NaN      NaN
# 31                 USD          3                   NaN      NaN
#
#                          sourceLink
# 117  http://lighttree.com/100055003
# 115  http://lighttree.com/100055001
# 123  http://lighttree.com/100055009
# 122  http://lighttree.com/100055008
# 121  http://lighttree.com/100055007
# ..                              ...
# 1    http://lighttree.com/100044350
# 21   http://lighttree.com/100044326
# 209  http://lighttree.com/100044330
# 22   http://lighttree.com/100044327
# 31   http://lighttree.com/100044337
#
# [214 rows x 20 columns]

# %% [markdown]
# ### Statistiques et agrégations :
#
# plusieurs méthodes, tout en précisant l'étique de la colonne sur laquelle on souhaite effectuer les opérations :
# - dataframe\["nomColonne"].mean() : **la moyenne arithmétique** selon l'étiquette de la colonne : **nomColonne**
# - dataframe\["nomColonne"].sum() : **la somme** de toutes les valeurs des enregistrements de la colonne: **nomColonne**
# - dataframe\["nomColonne"].max() : **la valeur maximale** selon l'étiquette de la colonne : **nomColonne**
# - dataframe\["nomColonne"].min() : **la valeur minimale** selon l'étiquette de la colonne : **nomColonne**

# %%
# nombre d'occurrences des valeurs dans la colonnes d'étiquette : "buyer.organizationIdentifier"
dataframe["buyer.organizationIdentifier"].value_counts()
# Out:
# buyer.organizationIdentifier
# LightTree    168
# CALTRAN       11
# AHTD           9
# QPWD           7
# COLA           5
# NYDOT          5
# FAA            4
# KYTC           3
# MAHD           2
# Name: count, dtype: int64

# %% [markdown]
# ### Enregistrer et exporter

# %%
dataframe.to_csv("nouveau_fichier.csv", index=False)  # Enregistre les données modifiées

# %% [markdown]
# #### Cela aurait pu se faire sous format **Excel** avec cette ligne de commande :
# **dataframe.to_excel("emplacement/mon_fichier.xlsx", index=False)**
